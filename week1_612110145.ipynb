# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# # Title 1
# ## Title 2
# ### Title 3
#
# description

# %%
2 + 3
# Out:
# 5

# %%
print ("Hello World")
# Out:
# Hello World

# %%
country = input("Where are you from = ")
# Out:
# Where are you from = thailand

# %%
print("I am from " + country)
# Out:
# I am from thailand

# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? yes

# %%
age = input("What is your age = ")
# Out:
# What is your age = 21

# %%
print("I am "+age+" !!")
# Out:
# I am 21 !!

# %%
tenyears_age = +int(age) + 10
print(tenyears_age)
# Out:
# 31

# %%
weight = input("what is your weight = ")
# Out:
# what is your weight = 50

# %%
print("I am "+weight+" " )
# Out:
# I am 50

# %%
print("I am " + weight)
# Out:
# I am 50

# %%
print("i am  "+weight+"  "+age+" "
     )
# Out:
# i am  50  21

# %%
age= 300
print(age
     )
# Out:
# 300

# %%
pi= 3.14
print(pi)
# Out:
# 3.14

# %%
print("The pi is equal to" +str(pi))
# Out:
# The pi is equal to3.14

# %%
age= 300 goal = "helloworld"
print(+int(age) + +str(goal)
     )
# Out:
#   File "<ipython-input-45-08d1f7ffb880>", line 1
#     age= 300 goal = "helloworld"
#                 ^
# SyntaxError: invalid syntax

# %%
a = input("what is your A = ")
b = input("what is your B = ")
# Out:
# what is your A = 30
# what is your B = 20

# %%
c = (+int(a) + +int(b))
print(c)
# Out:
# 50

# %% [markdown]
# ใช้ int เข้ามาช่วยบวก

# %%
my_string = "The direct ancestors of the Beothuks were a people who left behind tools and other objects that archaeologists call the Little Passage Complex named after the first recognized Little Passage site on Newfoundland's south coast. (The term complex is used by archaeologists to describe a pattern of similar tools used throughout a region over a period of time, particularly when comparatively little is known about the people who produced those tools). The most distinctive of the tools made by Little Passage people were arrowheads that were quite different from anything that had ever been made on the island of Newfoundland."
my_string.upper()
# Out:
# "THE DIRECT ANCESTORS OF THE BEOTHUKS WERE A PEOPLE WHO LEFT BEHIND TOOLS AND OTHER OBJECTS THAT ARCHAEOLOGISTS CALL THE LITTLE PASSAGE COMPLEX NAMED AFTER THE FIRST RECOGNIZED LITTLE PASSAGE SITE ON NEWFOUNDLAND'S SOUTH COAST. (THE TERM COMPLEX IS USED BY ARCHAEOLOGISTS TO DESCRIBE A PATTERN OF SIMILAR TOOLS USED THROUGHOUT A REGION OVER A PERIOD OF TIME, PARTICULARLY WHEN COMPARATIVELY LITTLE IS KNOWN ABOUT THE PEOPLE WHO PRODUCED THOSE TOOLS). THE MOST DISTINCTIVE OF THE TOOLS MADE BY LITTLE PASSAGE PEOPLE WERE ARROWHEADS THAT WERE QUITE DIFFERENT FROM ANYTHING THAT HAD EVER BEEN MADE ON THE ISLAND OF NEWFOUNDLAND."

# %%
my_string.replace("Complex","eiei")
# Out:
# "The direct ancestors of the Beothuks were a people who left behind tools and other objects that archaeologists call the Little Passage eiei named after the first recognized Little Passage site on Newfoundland's south coast. (The term complex is used by archaeologists to describe a pattern of similar tools used throughout a region over a period of time, particularly when comparatively little is known about the people who produced those tools). The most distinctive of the tools made by Little Passage people were arrowheads that were quite different from anything that had ever been made on the island of Newfoundland."

# %%
my_string.find("tools")
# Out:
# 67

# %%
my_string = "Hello World"
my_string.upper()
# Out:
# 'HELLO WORLD'

# %%
my_string.split()
# Out:
# ['Hello', 'World']

# %% [markdown]
# # split แบ่งคำ

# %%
L = [[1,2,3],
     [4,5,6],
     [7,8,9]]
L
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
L.sort(reverse = True)
L
# Out:
# [[7, 8, 9], [4, 5, 6], [1, 2, 3]]

# %%
L.reverse()
L
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
L.reverse()
L
# Out:
# [[7, 8, 9], [4, 5, 6], [1, 2, 3]]

# %%
L.sort(reverse = True)
L
# Out:
# [[7, 8, 9], [4, 5, 6], [1, 2, 3]]

# %%
L.sort()
L
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
L.reverse()
L
# Out:
# [[7, 8, 9], [4, 5, 6], [1, 2, 3]]

# %%
course = {
  "954340": "Enterprise Database",
  "954471": "Business Data Mining",
  "954472": "Business Data Visualization"
}
print(course)
# Out:
# {'954340': 'Enterprise Database', '954471': 'Business Data Mining', '954472': 'Business Data Visualization'}

# %%
sorted(course.values())
# Out:
# ['Business Data Mining', 'Business Data Visualization', 'Enterprise Database']

# %% [markdown]
# วิธีใช้ การเรียงตัวอักษรข้างใน
